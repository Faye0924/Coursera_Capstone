# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods - Search for Chinese Restaurant

# %% [markdown]
# ## Introduction
#   A Chinese restaurant is an establishment that serves a Chinese cuisine.
#
#   Chinese cuisine is an important part of Chinese culture, which includes cuisine originating from the diverse regions of China, as well as from Overseas Chinese who have settled in other parts of the world. Chinese food staples such as rice, dumpling, noodles, tea, and tofu, and utensils such as chopsticks and the wok, can now be found worldwide.
#
#   Many people including myself, love Chinese food, and always search for Chinese restaurants when traveling. However, Chinese cuisine is so diverse. The eight major traditions of Chinese cuisine are: Shandong cuisine, Sichuan cuisine, Cantonese cuisine, Fujian cuisine, Jiangsu cuisine, Zhejiang cuisine, Hunan cuisine, Anhui cuisine. Let along other traditional cuisine. In Foursquare, there are also Chinese restaurants belong to different categories, such as dim sum restaurants, dumpling restaurant, etc.
#
#   Therefore, if simply search for "Chinese restaurants", there will be some restaurants that actually belong to Chinese cuisine being left out. Also, some Foursquare data lack address or postalCode, which is essential for restaurant information.
#
#   So, the purpose of this project is to get all, at least most, Chinese restaurants' name, address and postalCode worldwide, for those who want to search for or provide others with Chinese restaurants information around a specific place.

# %% [markdown]
# ## Data
# #### Coordinates data
# Source: use geopy to get coordinates data. https://geopy.readthedocs.io/en/stable/
#
# Description: Includes searching places' and restaurants' latitude, longitude, address, etc. Latitude and longitude can used to get the postalCode and address for desired places; postalCode and address are part of Chinese restaurant information data provided for the final product, also for visualizing choropleth map.
#
# #### Restaurants data
# Source: Foursquare API
#
# Description: use Foursquare API to search for restaurants around a location, such as name, category, address, postalCode, etc. Then filter the data to get only clean Chinese restaurants information.

# %% [markdown]
# ## Methodology section
#
# This section represents the main component of the report where the data is gathered, prepared for analysis and mapping.
#
# ### Approach
#
# Use geopy library to get the latitude and longitude values of locations.
#
# Use Foursquare API to search all restaurants around a location.
#
# Clean the json and structure it into a pandas dataframe.
#
# Get all Chinese restaurants information, which includes:
# * Create a list to include all Chinese restaurants categories in Foursquare.
# * Use geopy library to replace NaN value in 'postalCode' and 'address' columns.
# * Select columns most related to audience for final display.
#
# Use Folium to Create a map of restaurants with name superimposed on top.
#
# ## Methodology Execution

# %% [markdown]
# #### Import necessary Libraries

# %%
import pandas as pd
import numpy as np
import requests
from pandas.io.json import json_normalize
#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
from pandas.io.json import json_normalize # transforming json file into a pandas dataframe library
print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### Search all restaurants around a location.
#   Since the purpose of this project is to get Chinese restaurants information around a location worldwide, some top visited cities will be tested on the final project, which are selected from **List of cities by international visitors** https://en.wikipedia.org/wiki/List_of_cities_by_international_visitors
#
#   But first, for building this project, Los Angeles,CA is chosen to start with, since it's known to have many Chinese restaurants nearby.

# %% [markdown]
# #### Specify a searching location
# Note: location can be changed.

# %%
address = 'Los Angeles, CA' # This can be changed to your interested city or location.

# %% [markdown]
# #### Use geopy library to get the latitude and longitude values of the searching location.

# %%
geolocator = Nominatim(user_agent="restaurant_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
# Out:
# The geograpical coordinate of Los Angeles, CA are 34.0536909, -118.2427666.

# %% [markdown]
# #### Utilizing the Foursquare API to search all restaurants around a location.
# Search "restaurants" instead of "Chinese restaurant" so no Chinese restaurants, such as dim sum restaurant will be left out.

# %%
# @hidden_cell
# Define Foursquare Credentials and Version
CLIENT_ID = 'xxxxxx' # Your Foursquare client_id
CLIENT_SECRET = 'xxxxxx' # Your Foursquare client_secret
VERSION = '20180605' # Foursquare API version

# %%
# Define search_query, radius and limit
search_query = 'restaurant'
radius = 10000 # takes about 6 minutes to drive at 60 mph speed, radius number can be changed.
LIMIT = 100

# %%
# Define URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=5RR4BF503NMA5Z3T1BVQDUFYH4D4KRESSO4TE1MCGVIUF4QC&client_secret=4KA5SMNYGO4GC5GE0QI4ROQRPMMFU5LS541FZ0NQWEH2Y5UB&ll=34.0536909,-118.2427666&v=20180605&query=restaurant&radius=10000&limit=100'

# %% [markdown]
# Send GET request and examine results.

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f3ccd71f26cab155cbb4f54'},
#  'response': {'venues': [{'id': '4aa8416bf964a5206c5020e3',
#     'name': 'Traxx Restaurant',
#     'location': {'address': '800 N Alameda St',
#      'crossStreet': 'in Union Station, along main corridor',
#      'lat': 34.056232294401845,
#      'lng': -118.23618342008349,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.056232294401845,
#        'lng': -118.23618342008349}],
#      'distance': 669,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['800 N Alameda St (in Union Station, along main corridor)',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d157941735',
#       'name': 'New American Restaurant',
#       'pluralName': 'New American Restaurants',
#       'shortName': 'New American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '89373347'},
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4b046029f964a520b15322e3',
#     'name': 'Mayflower Seafood Restaurant',
#     'location': {'address': '679 N Spring St',
#      'crossStreet': 'Ord',
#      'lat': 34.05958203122075,
#      'lng': -118.23812851129401,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05958203122075,
#        'lng': -118.23812851129401},
#       {'label': 'entrance', 'lat': 34.059572, 'lng': -118.238132}],
#      'distance': 782,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['679 N Spring St (Ord)',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ce941735',
#       'name': 'Seafood Restaurant',
#       'pluralName': 'Seafood Restaurants',
#       'shortName': 'Seafood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4a7e6011f964a520d4f11fe3',
#     'name': 'Noe Restaurant & Bar',
#     'location': {'address': '251 S Olive St',
#      'crossStreet': 'at the Omni Hotel',
#      'lat': 34.05229026588889,
#      'lng': -118.2509634668589,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05229026588889,
#        'lng': -118.2509634668589}],
#      'distance': 771,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['251 S Olive St (at the Omni Hotel)',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10c941735',
#       'name': 'French Restaurant',
#       'pluralName': 'French Restaurants',
#       'shortName': 'French',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '502209411'},
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4b87b6a5f964a5204dc831e3',
#     'name': '24/7 Restaurant at The Standard, Downtown LA',
#     'location': {'address': '550 S Flower St',
#      'crossStreet': '6th St. At The Standard Hotel',
#      'lat': 34.04974294912817,
#      'lng': -118.2565476507356,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.04974294912817,
#        'lng': -118.2565476507356}],
#      'distance': 1344,
#      'postalCode': '90071',
#      'cc': 'US',
#      'neighborhood': 'Financial District',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['550 S Flower St (6th St. At The Standard Hotel)',
#       'Los Angeles, CA 90071',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4e31b01962e1d3ed6511373e',
#     'name': 'Restaurant Guerrero',
#     'location': {'address': '320 W 8th St',
#      'lat': 34.044158935546875,
#      'lng': -118.255615234375,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 34.044106,
#        'lng': -118.255415},
#       {'label': 'display',
#        'lat': 34.044158935546875,
#        'lng': -118.255615234375}],
#      'distance': 1590,
#      'postalCode': '90014',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['320 W 8th St',
#       'Los Angeles, CA 90014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4415b1c5f964a520fd301fe3',
#     'name': 'Full House Seafood Restaurant',
#     'location': {'address': '963 N Hill St',
#      'lat': 34.06615468133357,
#      'lng': -118.23791638087025,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.06615468133357,
#        'lng': -118.23791638087025},
#       {'label': 'entrance', 'lat': 34.066195, 'lng': -118.237968}],
#      'distance': 1457,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['963 N Hill St',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1915321',
#      'url': 'https://www.grubhub.com/restaurant/full-house-seafood-restaurant-963-north-hill-street-los-angeles/1915321?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1915321',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '49ebc74af964a5202b671fe3',
#     'name': 'Yang Chow Restaurant',
#     'location': {'address': '819 N Broadway',
#      'crossStreet': 'btwn College & Alpine',
#      'lat': 34.06292584487055,
#      'lng': -118.2380586952736,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.06292584487055,
#        'lng': -118.2380586952736},
#       {'label': 'entrance', 'lat': 34.062969, 'lng': -118.238165}],
#      'distance': 1115,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['819 N Broadway (btwn College & Alpine)',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '48833648'},
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '5473e66d498ea620fcb58cd5',
#     'name': 'Amante Restaurant',
#     'location': {'address': '123 E 9th St',
#      'lat': 34.041190606609156,
#      'lng': -118.25448103463961,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.041190606609156,
#        'lng': -118.25448103463961}],
#      'distance': 1761,
#      'postalCode': '90015',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['123 E 9th St',
#       'Los Angeles, CA 90015',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '299242',
#      'url': 'https://www.grubhub.com/restaurant/amante-restaurant-123-e-9th-st-los-angeles/299242?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=299242',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '122524421'},
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4bcdedc6937ca5939097ad92',
#     'name': 'Trimana Restaurant',
#     'location': {'address': '633 W 5th St.',
#      'crossStreet': 'Hope St.',
#      'lat': 34.05081085783843,
#      'lng': -118.2549834122098,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05081085783843,
#        'lng': -118.2549834122098}],
#      'distance': 1171,
#      'postalCode': '90071',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['633 W 5th St. (Hope St.)',
#       'Los Angeles, CA 90071',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1bd941735',
#       'name': 'Salad Place',
#       'pluralName': 'Salad Places',
#       'shortName': 'Salad',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1914569',
#      'url': 'https://www.grubhub.com/restaurant/trimana-express-633-west-5th-street-los-angeles/1914569?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1914569',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4c59b2584ed9ef3b5bded96d',
#     'name': 'Wok Inn Restaurant',
#     'location': {'address': '201 N Los Angeles St Ste 102',
#      'crossStreet': 'btw Los Angeles & Main',
#      'lat': 34.0543171973882,
#      'lng': -118.24175235053629,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.0543171973882,
#        'lng': -118.24175235053629}],
#      'distance': 116,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['201 N Los Angeles St Ste 102 (btw Los Angeles & Main)',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4be31d431dd22d7fcbc195bd',
#     'name': 'Restaurant Atitlan',
#     'location': {'address': '1614 W 6th St',
#      'lat': 34.057095000000004,
#      'lng': -118.269879,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.057095000000004,
#        'lng': -118.269879},
#       {'label': 'entrance', 'lat': 34.057198, 'lng': -118.269897}],
#      'distance': 2529,
#      'postalCode': '90017',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1614 W 6th St',
#       'Los Angeles, CA 90017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1be941735',
#       'name': 'Latin American Restaurant',
#       'pluralName': 'Latin American Restaurants',
#       'shortName': 'Latin American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4c7d64ae3b22a1cd6dc95e9e',
#     'name': "Doña Vicky's Restaurant",
#     'location': {'address': '1263 W 2nd St',
#      'lat': 34.06019026649661,
#      'lng': -118.25779296419628,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.06019026649661,
#        'lng': -118.25779296419628},
#       {'label': 'entrance', 'lat': 34.060342, 'lng': -118.257627}],
#      'distance': 1563,
#      'postalCode': '90026',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1263 W 2nd St',
#       'Los Angeles, CA 90026',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4aca9a68f964a52081c220e3',
#     'name': 'Matsu Japanese Restaurant',
#     'location': {'address': '1267 W Temple St',
#      'crossStreet': 'Temple and Edgewater',
#      'lat': 34.066297999999996,
#      'lng': -118.25391699999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.066297999999996,
#        'lng': -118.25391699999999}],
#      'distance': 1739,
#      'postalCode': '90026',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1267 W Temple St (Temple and Edgewater)',
#       'Los Angeles, CA 90026',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4e1f523052b1bdc463eb6278',
#     'name': 'Lelit Restaurant',
#     'location': {'address': '109 E 9th St',
#      'lat': 34.041388,
#      'lng': -118.25455500000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.041388,
#        'lng': -118.25455500000001}],
#      'distance': 1748,
#      'postalCode': '90015',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['109 E 9th St',
#       'Los Angeles, CA 90015',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c0941735',
#       'name': 'Mediterranean Restaurant',
#       'pluralName': 'Mediterranean Restaurants',
#       'shortName': 'Mediterranean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4f3235c319836c91c7c0fef7',
#     'name': 'Gill’s Indian Restaurant| ORDER FOOD ONLINE',
#     'location': {'address': '838 S Grand Ave',
#      'lat': 34.0446474,
#      'lng': -118.258433,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.0446474,
#        'lng': -118.258433}],
#      'distance': 1761,
#      'postalCode': '90017',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['838 S Grand Ave',
#       'Los Angeles, CA 90017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4f1b4db8e4b0d1a655940fa4',
#     'name': 'La Guadalupana Restaurant',
#     'location': {'address': 'Idk',
#      'lat': 34.052236329657745,
#      'lng': -118.24368255726505,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.052236329657745,
#        'lng': -118.24368255726505}],
#      'distance': 182,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Idk', 'Los Angeles, CA 90012', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '49ed71e7f964a520eb671fe3',
#     'name': 'Won Kok Restaurant',
#     'location': {'address': '210 Alpine St',
#      'crossStreet': 'Broadway',
#      'lat': 34.06195782693353,
#      'lng': -118.2375086211258,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.06195782693353,
#        'lng': -118.2375086211258},
#       {'label': 'entrance', 'lat': 34.061898, 'lng': -118.23756}],
#      'distance': 1040,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['210 Alpine St (Broadway)',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1918673',
#      'url': 'https://www.grubhub.com/restaurant/won-kok-restaurant-210-alpine-street-los-angeles/1918673?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1918673',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4f32981f19836c91c7e7066e',
#     'name': 'Rikyu Restaurant',
#     'location': {'address': '123 Astronaut E S Onizuka St',
#      'lat': 34.050814,
#      'lng': -118.24203,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.050814,
#        'lng': -118.24203}],
#      'distance': 327,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['123 Astronaut E S Onizuka St',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4b9c6520f964a5207e6536e3',
#     'name': 'Restaurant Spain',
#     'location': {'address': '1866 Glendale Blvd',
#      'crossStreet': '2 Freeway',
#      'lat': 34.089681130642724,
#      'lng': -118.25883750797084,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.089681130642724,
#        'lng': -118.25883750797084},
#       {'label': 'entrance', 'lat': 34.089467, 'lng': -118.258935}],
#      'distance': 4271,
#      'postalCode': '90026',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1866 Glendale Blvd (2 Freeway)',
#       'Los Angeles, CA 90026',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d150941735',
#       'name': 'Spanish Restaurant',
#       'pluralName': 'Spanish Restaurants',
#       'shortName': 'Spanish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '304883',
#      'url': 'https://www.grubhub.com/restaurant/spain-restaurant-1866-glendale-blvd-los-angeles/304883?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=304883',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '43d21a6cf964a5200a2e1fe3',
#     'name': 'Taix French Restaurant',
#     'location': {'address': '1911 W Sunset Blvd',
#      'crossStreet': 'at Glendale Blvd.',
#      'lat': 34.078103415800804,
#      'lng': -118.26157508658508,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.078103415800804,
#        'lng': -118.26157508658508}],
#      'distance': 3223,
#      'postalCode': '90026',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1911 W Sunset Blvd (at Glendale Blvd.)',
#       'Los Angeles, CA 90026',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10c941735',
#       'name': 'French Restaurant',
#       'pluralName': 'French Restaurants',
#       'shortName': 'French',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '343328',
#      'url': 'https://www.grubhub.com/restaurant/taix-1911-sunset-blvd-los-angeles/343328?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=343328',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '70599028'},
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '5bae0e7ecabcff003996f184',
#     'name': '360 Restaurant Design',
#     'location': {'address': '8055 Manchester Avenue Suite 230A',
#      'lat': 34.05182384275727,
#      'lng': -118.24601054191588,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05182384275727,
#        'lng': -118.24601054191588}],
#      'distance': 364,
#      'postalCode': '90045',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['8055 Manchester Avenue Suite 230A',
#       'Los Angeles, CA 90045',
#       'United States']},
#     'categories': [{'id': '5454144b498ec1f095bff2f2',
#       'name': 'Construction & Landscaping',
#       'pluralName': 'Construction & Landscaping',
#       'shortName': 'Construction',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4ba95decf964a5205a223ae3',
#     'name': 'Market Restaurant',
#     'location': {'address': '862 S Los Angeles St',
#      'crossStreet': 'Cooper Building Lobby',
#      'lat': 34.04084212262895,
#      'lng': -118.25391012679295,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.04084212262895,
#        'lng': -118.25391012679295}],
#      'distance': 1761,
#      'postalCode': '90014',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['862 S Los Angeles St (Cooper Building Lobby)',
#       'Los Angeles, CA 90014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2208158',
#      'url': 'https://www.grubhub.com/restaurant/market-restaurant-862-s-los-angeles-st-los-angeles/2208158?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2208158',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4f32221219836c91c7b959ae',
#     'name': 'Japanese Restaurant Association of Southern California',
#     'location': {'address': '324 E 1st St',
#      'lat': 34.050188,
#      'lng': -118.240606,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.050188,
#        'lng': -118.240606}],
#      'distance': 437,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['324 E 1st St',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4f327c1a19836c91c7dc5a4a',
#     'name': 'Daisuke Japanese Restaurant',
#     'location': {'address': '123 Astronaut E S Onizuka St',
#      'lat': 34.049786,
#      'lng': -118.241928,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.049786,
#        'lng': -118.241928}],
#      'distance': 441,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['123 Astronaut E S Onizuka St',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4a52b210f964a520eeb11fe3',
#     'name': 'East Japanese Restaurant',
#     'location': {'address': '329 1st St',
#      'lat': 34.049832,
#      'lng': -118.240224,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.049832,
#        'lng': -118.240224}],
#      'distance': 489,
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['329 1st St', 'Los Angeles, CA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '5c708ab5aa6c950039227d59',
#     'name': 'Hill Street Bar & Restaurant',
#     'location': {'address': '200 S Hill St',
#      'lat': 34.052738,
#      'lng': -118.247693,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.052738,
#        'lng': -118.247693}],
#      'distance': 466,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['200 S Hill St',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1589615',
#      'url': 'https://www.grubhub.com/restaurant/hill-street-bar--restaurant-200-south-hill-street-los-angeles/1589615?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1589615',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4b8a2ff9f964a520596332e3',
#     'name': 'Paraiso Restaurant',
#     'location': {'address': '115 W 3rd St',
#      'lat': 34.049955,
#      'lng': -118.245994,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.049955,
#        'lng': -118.245994},
#       {'label': 'entrance', 'lat': 34.049884, 'lng': -118.246183}],
#      'distance': 511,
#      'postalCode': '90013',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['115 W 3rd St',
#       'Los Angeles, CA 90013',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4dd1a37a227159fef239769a',
#     'name': 'Keung Kee B.B.Q. Restaurant',
#     'location': {'address': '420 Ord St',
#      'crossStreet': 'Hill st',
#      'lat': 34.0604362487793,
#      'lng': -118.24009704589844,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.0604362487793,
#        'lng': -118.24009704589844}],
#      'distance': 790,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['420 Ord St (Hill st)',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2187700',
#      'url': 'https://www.grubhub.com/restaurant/keung-kee-bbq-420-ord-st-los-angeles/2187700?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2187700',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '50d36050498ebcf92ba1ecff',
#     'name': 'El Venado Bakery and Restaurant',
#     'location': {'address': '1007 S Alvarado St',
#      'crossStreet': 'Olympic',
#      'lat': 34.051704218127185,
#      'lng': -118.28047795612379,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.051704218127185,
#        'lng': -118.28047795612379}],
#      'distance': 3485,
#      'postalCode': '90006',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1007 S Alvarado St (Olympic)',
#       'Los Angeles, CA 90006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1be941735',
#       'name': 'Latin American Restaurant',
#       'pluralName': 'Latin American Restaurants',
#       'shortName': 'Latin American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1912701',
#      'url': 'https://www.grubhub.com/restaurant/el-venado-bakery-and-restaurant-1007-south-alvarado-street-los-angeles/1912701?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1912701',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '80752779'},
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '55abc10f498e73eddd7ab75d',
#     'name': 'Little Sagion International Restaurant Group Headquarters 小西龚越南美食集团',
#     'location': {'address': 'Los Angeles',
#      'crossStreet': 'United States',
#      'lat': 34.050088,
#      'lng': -118.240379,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.050088,
#        'lng': -118.240379}],
#      'distance': 457,
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles (United States)',
#       'Los Angeles, CA',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4b9d5b02f964a52054a636e3',
#     'name': 'Colima Restaurant',
#     'location': {'address': '400 W Cesar E Chavez Ave',
#      'lat': 34.05858,
#      'lng': -118.24042,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05858,
#        'lng': -118.24042},
#       {'label': 'entrance', 'lat': 34.058523, 'lng': -118.24049}],
#      'distance': 585,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['400 W Cesar E Chavez Ave',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4d01711b725e60fc040041b9',
#     'name': 'Oiwake Restaurant & Karaoke Bar',
#     'location': {'address': '122 Japanese Village Plaza Mall',
#      'lat': 34.04895545821701,
#      'lng': -118.23994019816385,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.04895545821701,
#        'lng': -118.23994019816385},
#       {'label': 'entrance', 'lat': 34.048914, 'lng': -118.240246}],
#      'distance': 588,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['122 Japanese Village Plaza Mall',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d120941735',
#       'name': 'Karaoke Bar',
#       'pluralName': 'Karaoke Bars',
#       'shortName': 'Karaoke',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/karaoke_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '50ec744819a92ef6c73fbfaa',
#     'name': 'Grouper Social Club at Weiland Brewery Restaurant',
#     'location': {'address': '400 E 1st St',
#      'crossStreet': 'btwn S Alameda St & S Central Ave',
#      'lat': 34.04893112182617,
#      'lng': -118.23892974853516,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.04893112182617,
#        'lng': -118.23892974853516}],
#      'distance': 637,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['400 E 1st St (btwn S Alameda St & S Central Ave)',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11a941735',
#       'name': 'Other Nightlife',
#       'pluralName': 'Other Nightlife',
#       'shortName': 'Nightlife',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '5780568f498e9934ec69d3b6',
#     'name': 'Los Compadres Restaurant',
#     'location': {'address': '633 N Spring St',
#      'lat': 34.05841827392578,
#      'lng': -118.2387466430664,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05841827392578,
#        'lng': -118.2387466430664}],
#      'distance': 643,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['633 N Spring St',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4cdf4668df986ea87a45e116',
#     'name': 'Fred Harvey Restaurant',
#     'location': {'lat': 34.05577711870245,
#      'lng': -118.23664119524993,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05577711870245,
#        'lng': -118.23664119524993}],
#      'distance': 610,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles, CA 90012', 'United States']},
#     'categories': [],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4c65d89ac2ead13a1a44b280',
#     'name': 'El Delfin Restaurant',
#     'location': {'address': '1800 S Central Ave',
#      'crossStreet': '18th St',
#      'lat': 34.025071171012065,
#      'lng': -118.2498004455827,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.025071171012065,
#        'lng': -118.2498004455827}],
#      'distance': 3251,
#      'postalCode': '90021',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1800 S Central Ave (18th St)',
#       'Los Angeles, CA 90021',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1917805',
#      'url': 'https://www.grubhub.com/restaurant/el-delfin-restaurant-1800-south-central-avenue-los-angeles/1917805?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1917805',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4c37da4ddfb0e21e97a8ada8',
#     'name': "Mandini's Family Restaurant",
#     'location': {'address': '2021 W 3rd St',
#      'crossStreet': 'Alvarado',
#      'lat': 34.063011169433594,
#      'lng': -118.27182006835938,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.063011169433594,
#        'lng': -118.27182006835938}],
#      'distance': 2873,
#      'postalCode': '90057',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2021 W 3rd St (Alvarado)',
#       'Los Angeles, CA 90057',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4ad930fcf964a520f61821e3',
#     'name': 'Ruen Pair Thai Restaurant',
#     'location': {'address': '5257 Hollywood Blvd',
#      'crossStreet': 'at N Hobart Blvd',
#      'lat': 34.10203547642684,
#      'lng': -118.30560382956727,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10203547642684,
#        'lng': -118.30560382956727},
#       {'label': 'entrance', 'lat': 34.101873, 'lng': -118.305407}],
#      'distance': 7907,
#      'postalCode': '90027',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['5257 Hollywood Blvd (at N Hobart Blvd)',
#       'Los Angeles, CA 90027',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4df1298522710ce8f79789be',
#     'name': 'Otomisan Japanese Restaurant',
#     'location': {'address': '2506 1/2 E 1st St',
#      'lat': 34.04305659885357,
#      'lng': -118.20838034660254,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.04305659885357,
#        'lng': -118.20838034660254},
#       {'label': 'entrance', 'lat': 34.042975, 'lng': -118.208404}],
#      'distance': 3385,
#      'postalCode': '90033',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2506 1/2 E 1st St',
#       'Los Angeles, CA 90033',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1590474',
#      'url': 'https://www.grubhub.com/restaurant/otomisan-restaurant-2506-east-1st-street-los-angeles/1590474?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1590474',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '43ee0ffef964a5205e2f1fe3',
#     'name': 'Astro Family Restaurant',
#     'location': {'address': '2300 Fletcher Dr',
#      'crossStreet': 'at Glendale Blvd',
#      'lat': 34.10460607934933,
#      'lng': -118.25884253377507,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.10460607934933,
#        'lng': -118.25884253377507},
#       {'label': 'entrance', 'lat': 34.104533, 'lng': -118.258831}],
#      'distance': 5858,
#      'postalCode': '90039',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['2300 Fletcher Dr (at Glendale Blvd)',
#       'Los Angeles, CA 90039',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '319398',
#      'url': 'https://www.grubhub.com/restaurant/astro-family-2300-fletcher-dr-los-angeles/319398?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=319398',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4f32af4d19836c91c7efafbf',
#     'name': "O'Dom Bang Restaurant",
#     'location': {'address': '648 New High St',
#      'lat': 34.05958938598633,
#      'lng': -118.23826599121094,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 34.059531,
#        'lng': -118.238155},
#       {'label': 'display',
#        'lat': 34.05958938598633,
#        'lng': -118.23826599121094}],
#      'distance': 776,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['648 New High St',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4cd73d702944b1f7585e67ec',
#     'name': 'Hong Kong BBQ Restaurant',
#     'location': {'address': '803 N Broadway',
#      'crossStreet': 'at Alpine St.',
#      'lat': 34.06252029091686,
#      'lng': -118.23824936956532,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.06252029091686,
#        'lng': -118.23824936956532},
#       {'label': 'entrance', 'lat': 34.062541, 'lng': -118.238351}],
#      'distance': 1067,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['803 N Broadway (at Alpine St.)',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1645630',
#      'url': 'https://www.grubhub.com/restaurant/hong-kong-bbq-803-north-broadway-los-angeles/1645630?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1645630',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4b6c7385f964a520313b2ce3',
#     'name': 'Almas restaurant',
#     'location': {'address': '1403 Hooper Ave',
#      'crossStreet': 'btw 14th street',
#      'lat': 34.02644434065198,
#      'lng': -118.24325425883144,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.02644434065198,
#        'lng': -118.24325425883144}],
#      'distance': 3033,
#      'postalCode': '90021',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['1403 Hooper Ave (btw 14th street)',
#       'Los Angeles, CA 90021',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4c00d9439cf52d7f636714e7',
#     'name': 'Hae Jang Chon Korean BBQ Restaurant',
#     'location': {'address': '3821 West 6th Street',
#      'lat': 34.0638885,
#      'lng': -118.3060754,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.0638885,
#        'lng': -118.3060754}],
#      'distance': 5947,
#      'postalCode': '90020',
#      'cc': 'US',
#      'neighborhood': 'Wilshire Center - Koreatown',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['3821 West 6th Street',
#       'Los Angeles, CA 90020',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1591634',
#      'url': 'https://www.grubhub.com/restaurant/hae-jang-chon-korean-bbq-restaurant-3821-west-6th-street-los-angeles/1591634?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1591634',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '79599419'},
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4b3c2d94f964a520a38225e3',
#     'name': 'Hop Woo BBQ Seafood Restaurant',
#     'location': {'address': '845 N Broadway',
#      'lat': 34.06364617250033,
#      'lng': -118.23766989273867,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.06364617250033,
#        'lng': -118.23766989273867},
#       {'label': 'entrance', 'lat': 34.063632, 'lng': -118.237803}],
#      'distance': 1203,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['845 N Broadway',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '314482',
#      'url': 'https://www.grubhub.com/restaurant/hop-woo-bbq-and-seafood-chinese-restaurant-845-n-broadway-blvd-los-angeles/314482?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=314482',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4fc40809e4b012f50039ddd1',
#     'name': 'Friendly Seafood Restaurant',
#     'location': {'lat': 34.06130599975586,
#      'lng': -118.23933410644531,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.06130599975586,
#        'lng': -118.23933410644531}],
#      'distance': 904,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['Los Angeles, CA 90012', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4f322ef319836c91c7be56a2',
#     'name': 'Viet Huong Restaurant',
#     'location': {'address': '727 N Broadway',
#      'lat': 34.06130599975586,
#      'lng': -118.23933410644531,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.06130599975586,
#        'lng': -118.23933410644531}],
#      'distance': 904,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['727 N Broadway',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4ef7aa39be7bb4784dd3d06f',
#     'name': 'thanh vi restaurant',
#     'location': {'address': '422 Ord St',
#      'lat': 34.06077009373006,
#      'lng': -118.24026185059148,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.06077009373006,
#        'lng': -118.24026185059148}],
#      'distance': 821,
#      'postalCode': '90012',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['422 Ord St',
#       'Los Angeles, CA 90012',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4f32699719836c91c7d55134',
#     'name': 'Tai Pan Restaurant',
#     'location': {'address': '330 S Hope St',
#      'lat': 34.05334,
#      'lng': -118.252679,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.05334,
#        'lng': -118.252679}],
#      'distance': 915,
#      'postalCode': '90071',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['330 S Hope St',
#       'Los Angeles, CA 90071',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False},
#    {'id': '4d01be9e3be26dcbd88374e4',
#     'name': 'Coronado’s Mexican Restaurant & Bar',
#     'location': {'address': '212 W 5th St',
#      'crossStreet': 'at Spring St',
#      'lat': 34.04768646419671,
#      'lng': -118.25002199566127,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 34.04768646419671,
#        'lng': -118.25002199566127},
#       {'label': 'entrance', 'lat': 34.04756, 'lng': -118.250041}],
#      'distance': 945,
#      'postalCode': '90013',
#      'cc': 'US',
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'country': 'United States',
#      'formattedAddress': ['212 W 5th St (at Spring St)',
#       'Los Angeles, CA 90013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597820453',
#     'hasPerk': False}]}}

# %%
# Get relevant part of JSON. 
venues = results['response']['venues']
venues
# Out:
# [{'id': '4aa8416bf964a5206c5020e3',
#   'name': 'Traxx Restaurant',
#   'location': {'address': '800 N Alameda St',
#    'crossStreet': 'in Union Station, along main corridor',
#    'lat': 34.056232294401845,
#    'lng': -118.23618342008349,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.056232294401845,
#      'lng': -118.23618342008349}],
#    'distance': 669,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['800 N Alameda St (in Union Station, along main corridor)',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d157941735',
#     'name': 'New American Restaurant',
#     'pluralName': 'New American Restaurants',
#     'shortName': 'New American',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#      'suffix': '.png'},
#     'primary': True}],
#   'venuePage': {'id': '89373347'},
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4b046029f964a520b15322e3',
#   'name': 'Mayflower Seafood Restaurant',
#   'location': {'address': '679 N Spring St',
#    'crossStreet': 'Ord',
#    'lat': 34.05958203122075,
#    'lng': -118.23812851129401,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.05958203122075,
#      'lng': -118.23812851129401},
#     {'label': 'entrance', 'lat': 34.059572, 'lng': -118.238132}],
#    'distance': 782,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['679 N Spring St (Ord)',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1ce941735',
#     'name': 'Seafood Restaurant',
#     'pluralName': 'Seafood Restaurants',
#     'shortName': 'Seafood',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4a7e6011f964a520d4f11fe3',
#   'name': 'Noe Restaurant & Bar',
#   'location': {'address': '251 S Olive St',
#    'crossStreet': 'at the Omni Hotel',
#    'lat': 34.05229026588889,
#    'lng': -118.2509634668589,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.05229026588889,
#      'lng': -118.2509634668589}],
#    'distance': 771,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['251 S Olive St (at the Omni Hotel)',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d10c941735',
#     'name': 'French Restaurant',
#     'pluralName': 'French Restaurants',
#     'shortName': 'French',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#      'suffix': '.png'},
#     'primary': True}],
#   'venuePage': {'id': '502209411'},
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4b87b6a5f964a5204dc831e3',
#   'name': '24/7 Restaurant at The Standard, Downtown LA',
#   'location': {'address': '550 S Flower St',
#    'crossStreet': '6th St. At The Standard Hotel',
#    'lat': 34.04974294912817,
#    'lng': -118.2565476507356,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.04974294912817,
#      'lng': -118.2565476507356}],
#    'distance': 1344,
#    'postalCode': '90071',
#    'cc': 'US',
#    'neighborhood': 'Financial District',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['550 S Flower St (6th St. At The Standard Hotel)',
#     'Los Angeles, CA 90071',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d14e941735',
#     'name': 'American Restaurant',
#     'pluralName': 'American Restaurants',
#     'shortName': 'American',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4e31b01962e1d3ed6511373e',
#   'name': 'Restaurant Guerrero',
#   'location': {'address': '320 W 8th St',
#    'lat': 34.044158935546875,
#    'lng': -118.255615234375,
#    'labeledLatLngs': [{'label': 'entrance',
#      'lat': 34.044106,
#      'lng': -118.255415},
#     {'label': 'display', 'lat': 34.044158935546875, 'lng': -118.255615234375}],
#    'distance': 1590,
#    'postalCode': '90014',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['320 W 8th St',
#     'Los Angeles, CA 90014',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1c1941735',
#     'name': 'Mexican Restaurant',
#     'pluralName': 'Mexican Restaurants',
#     'shortName': 'Mexican',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4415b1c5f964a520fd301fe3',
#   'name': 'Full House Seafood Restaurant',
#   'location': {'address': '963 N Hill St',
#    'lat': 34.06615468133357,
#    'lng': -118.23791638087025,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.06615468133357,
#      'lng': -118.23791638087025},
#     {'label': 'entrance', 'lat': 34.066195, 'lng': -118.237968}],
#    'distance': 1457,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['963 N Hill St',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d145941735',
#     'name': 'Chinese Restaurant',
#     'pluralName': 'Chinese Restaurants',
#     'shortName': 'Chinese',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'delivery': {'id': '1915321',
#    'url': 'https://www.grubhub.com/restaurant/full-house-seafood-restaurant-963-north-hill-street-los-angeles/1915321?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1915321',
#    'provider': {'name': 'grubhub',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_grubhub_20180129.png'}}},
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '49ebc74af964a5202b671fe3',
#   'name': 'Yang Chow Restaurant',
#   'location': {'address': '819 N Broadway',
#    'crossStreet': 'btwn College & Alpine',
#    'lat': 34.06292584487055,
#    'lng': -118.2380586952736,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.06292584487055,
#      'lng': -118.2380586952736},
#     {'label': 'entrance', 'lat': 34.062969, 'lng': -118.238165}],
#    'distance': 1115,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['819 N Broadway (btwn College & Alpine)',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d145941735',
#     'name': 'Chinese Restaurant',
#     'pluralName': 'Chinese Restaurants',
#     'shortName': 'Chinese',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'venuePage': {'id': '48833648'},
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '5473e66d498ea620fcb58cd5',
#   'name': 'Amante Restaurant',
#   'location': {'address': '123 E 9th St',
#    'lat': 34.041190606609156,
#    'lng': -118.25448103463961,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.041190606609156,
#      'lng': -118.25448103463961}],
#    'distance': 1761,
#    'postalCode': '90015',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['123 E 9th St',
#     'Los Angeles, CA 90015',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d110941735',
#     'name': 'Italian Restaurant',
#     'pluralName': 'Italian Restaurants',
#     'shortName': 'Italian',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'delivery': {'id': '299242',
#    'url': 'https://www.grubhub.com/restaurant/amante-restaurant-123-e-9th-st-los-angeles/299242?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=299242',
#    'provider': {'name': 'grubhub',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_grubhub_20180129.png'}}},
#   'venuePage': {'id': '122524421'},
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4bcdedc6937ca5939097ad92',
#   'name': 'Trimana Restaurant',
#   'location': {'address': '633 W 5th St.',
#    'crossStreet': 'Hope St.',
#    'lat': 34.05081085783843,
#    'lng': -118.2549834122098,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.05081085783843,
#      'lng': -118.2549834122098}],
#    'distance': 1171,
#    'postalCode': '90071',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['633 W 5th St. (Hope St.)',
#     'Los Angeles, CA 90071',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1bd941735',
#     'name': 'Salad Place',
#     'pluralName': 'Salad Places',
#     'shortName': 'Salad',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#      'suffix': '.png'},
#     'primary': True}],
#   'delivery': {'id': '1914569',
#    'url': 'https://www.grubhub.com/restaurant/trimana-express-633-west-5th-street-los-angeles/1914569?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1914569',
#    'provider': {'name': 'grubhub',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_grubhub_20180129.png'}}},
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4c59b2584ed9ef3b5bded96d',
#   'name': 'Wok Inn Restaurant',
#   'location': {'address': '201 N Los Angeles St Ste 102',
#    'crossStreet': 'btw Los Angeles & Main',
#    'lat': 34.0543171973882,
#    'lng': -118.24175235053629,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.0543171973882,
#      'lng': -118.24175235053629}],
#    'distance': 116,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['201 N Los Angeles St Ste 102 (btw Los Angeles & Main)',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d142941735',
#     'name': 'Asian Restaurant',
#     'pluralName': 'Asian Restaurants',
#     'shortName': 'Asian',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4be31d431dd22d7fcbc195bd',
#   'name': 'Restaurant Atitlan',
#   'location': {'address': '1614 W 6th St',
#    'lat': 34.057095000000004,
#    'lng': -118.269879,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.057095000000004,
#      'lng': -118.269879},
#     {'label': 'entrance', 'lat': 34.057198, 'lng': -118.269897}],
#    'distance': 2529,
#    'postalCode': '90017',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['1614 W 6th St',
#     'Los Angeles, CA 90017',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1be941735',
#     'name': 'Latin American Restaurant',
#     'pluralName': 'Latin American Restaurants',
#     'shortName': 'Latin American',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4c7d64ae3b22a1cd6dc95e9e',
#   'name': "Doña Vicky's Restaurant",
#   'location': {'address': '1263 W 2nd St',
#    'lat': 34.06019026649661,
#    'lng': -118.25779296419628,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.06019026649661,
#      'lng': -118.25779296419628},
#     {'label': 'entrance', 'lat': 34.060342, 'lng': -118.257627}],
#    'distance': 1563,
#    'postalCode': '90026',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['1263 W 2nd St',
#     'Los Angeles, CA 90026',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1c1941735',
#     'name': 'Mexican Restaurant',
#     'pluralName': 'Mexican Restaurants',
#     'shortName': 'Mexican',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4aca9a68f964a52081c220e3',
#   'name': 'Matsu Japanese Restaurant',
#   'location': {'address': '1267 W Temple St',
#    'crossStreet': 'Temple and Edgewater',
#    'lat': 34.066297999999996,
#    'lng': -118.25391699999999,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.066297999999996,
#      'lng': -118.25391699999999}],
#    'distance': 1739,
#    'postalCode': '90026',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['1267 W Temple St (Temple and Edgewater)',
#     'Los Angeles, CA 90026',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1d2941735',
#     'name': 'Sushi Restaurant',
#     'pluralName': 'Sushi Restaurants',
#     'shortName': 'Sushi',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4e1f523052b1bdc463eb6278',
#   'name': 'Lelit Restaurant',
#   'location': {'address': '109 E 9th St',
#    'lat': 34.041388,
#    'lng': -118.25455500000001,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.041388,
#      'lng': -118.25455500000001}],
#    'distance': 1748,
#    'postalCode': '90015',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['109 E 9th St',
#     'Los Angeles, CA 90015',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1c0941735',
#     'name': 'Mediterranean Restaurant',
#     'pluralName': 'Mediterranean Restaurants',
#     'shortName': 'Mediterranean',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4f3235c319836c91c7c0fef7',
#   'name': 'Gill’s Indian Restaurant| ORDER FOOD ONLINE',
#   'location': {'address': '838 S Grand Ave',
#    'lat': 34.0446474,
#    'lng': -118.258433,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.0446474,
#      'lng': -118.258433}],
#    'distance': 1761,
#    'postalCode': '90017',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['838 S Grand Ave',
#     'Los Angeles, CA 90017',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d10f941735',
#     'name': 'Indian Restaurant',
#     'pluralName': 'Indian Restaurants',
#     'shortName': 'Indian',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4f1b4db8e4b0d1a655940fa4',
#   'name': 'La Guadalupana Restaurant',
#   'location': {'address': 'Idk',
#    'lat': 34.052236329657745,
#    'lng': -118.24368255726505,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.052236329657745,
#      'lng': -118.24368255726505}],
#    'distance': 182,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['Idk', 'Los Angeles, CA 90012', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1c1941735',
#     'name': 'Mexican Restaurant',
#     'pluralName': 'Mexican Restaurants',
#     'shortName': 'Mexican',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '49ed71e7f964a520eb671fe3',
#   'name': 'Won Kok Restaurant',
#   'location': {'address': '210 Alpine St',
#    'crossStreet': 'Broadway',
#    'lat': 34.06195782693353,
#    'lng': -118.2375086211258,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.06195782693353,
#      'lng': -118.2375086211258},
#     {'label': 'entrance', 'lat': 34.061898, 'lng': -118.23756}],
#    'distance': 1040,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['210 Alpine St (Broadway)',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d145941735',
#     'name': 'Chinese Restaurant',
#     'pluralName': 'Chinese Restaurants',
#     'shortName': 'Chinese',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'delivery': {'id': '1918673',
#    'url': 'https://www.grubhub.com/restaurant/won-kok-restaurant-210-alpine-street-los-angeles/1918673?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1918673',
#    'provider': {'name': 'grubhub',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_grubhub_20180129.png'}}},
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4f32981f19836c91c7e7066e',
#   'name': 'Rikyu Restaurant',
#   'location': {'address': '123 Astronaut E S Onizuka St',
#    'lat': 34.050814,
#    'lng': -118.24203,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.050814,
#      'lng': -118.24203}],
#    'distance': 327,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['123 Astronaut E S Onizuka St',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d111941735',
#     'name': 'Japanese Restaurant',
#     'pluralName': 'Japanese Restaurants',
#     'shortName': 'Japanese',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4b9c6520f964a5207e6536e3',
#   'name': 'Restaurant Spain',
#   'location': {'address': '1866 Glendale Blvd',
#    'crossStreet': '2 Freeway',
#    'lat': 34.089681130642724,
#    'lng': -118.25883750797084,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.089681130642724,
#      'lng': -118.25883750797084},
#     {'label': 'entrance', 'lat': 34.089467, 'lng': -118.258935}],
#    'distance': 4271,
#    'postalCode': '90026',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['1866 Glendale Blvd (2 Freeway)',
#     'Los Angeles, CA 90026',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d150941735',
#     'name': 'Spanish Restaurant',
#     'pluralName': 'Spanish Restaurants',
#     'shortName': 'Spanish',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#      'suffix': '.png'},
#     'primary': True}],
#   'delivery': {'id': '304883',
#    'url': 'https://www.grubhub.com/restaurant/spain-restaurant-1866-glendale-blvd-los-angeles/304883?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=304883',
#    'provider': {'name': 'grubhub',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_grubhub_20180129.png'}}},
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '43d21a6cf964a5200a2e1fe3',
#   'name': 'Taix French Restaurant',
#   'location': {'address': '1911 W Sunset Blvd',
#    'crossStreet': 'at Glendale Blvd.',
#    'lat': 34.078103415800804,
#    'lng': -118.26157508658508,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.078103415800804,
#      'lng': -118.26157508658508}],
#    'distance': 3223,
#    'postalCode': '90026',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['1911 W Sunset Blvd (at Glendale Blvd.)',
#     'Los Angeles, CA 90026',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d10c941735',
#     'name': 'French Restaurant',
#     'pluralName': 'French Restaurants',
#     'shortName': 'French',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#      'suffix': '.png'},
#     'primary': True}],
#   'delivery': {'id': '343328',
#    'url': 'https://www.grubhub.com/restaurant/taix-1911-sunset-blvd-los-angeles/343328?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=343328',
#    'provider': {'name': 'grubhub',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_grubhub_20180129.png'}}},
#   'venuePage': {'id': '70599028'},
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '5bae0e7ecabcff003996f184',
#   'name': '360 Restaurant Design',
#   'location': {'address': '8055 Manchester Avenue Suite 230A',
#    'lat': 34.05182384275727,
#    'lng': -118.24601054191588,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.05182384275727,
#      'lng': -118.24601054191588}],
#    'distance': 364,
#    'postalCode': '90045',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['8055 Manchester Avenue Suite 230A',
#     'Los Angeles, CA 90045',
#     'United States']},
#   'categories': [{'id': '5454144b498ec1f095bff2f2',
#     'name': 'Construction & Landscaping',
#     'pluralName': 'Construction & Landscaping',
#     'shortName': 'Construction',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4ba95decf964a5205a223ae3',
#   'name': 'Market Restaurant',
#   'location': {'address': '862 S Los Angeles St',
#    'crossStreet': 'Cooper Building Lobby',
#    'lat': 34.04084212262895,
#    'lng': -118.25391012679295,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.04084212262895,
#      'lng': -118.25391012679295}],
#    'distance': 1761,
#    'postalCode': '90014',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['862 S Los Angeles St (Cooper Building Lobby)',
#     'Los Angeles, CA 90014',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1c4941735',
#     'name': 'Restaurant',
#     'pluralName': 'Restaurants',
#     'shortName': 'Restaurant',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#      'suffix': '.png'},
#     'primary': True}],
#   'delivery': {'id': '2208158',
#    'url': 'https://www.grubhub.com/restaurant/market-restaurant-862-s-los-angeles-st-los-angeles/2208158?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2208158',
#    'provider': {'name': 'grubhub',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_grubhub_20180129.png'}}},
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4f32221219836c91c7b959ae',
#   'name': 'Japanese Restaurant Association of Southern California',
#   'location': {'address': '324 E 1st St',
#    'lat': 34.050188,
#    'lng': -118.240606,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.050188,
#      'lng': -118.240606}],
#    'distance': 437,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['324 E 1st St',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d111941735',
#     'name': 'Japanese Restaurant',
#     'pluralName': 'Japanese Restaurants',
#     'shortName': 'Japanese',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4f327c1a19836c91c7dc5a4a',
#   'name': 'Daisuke Japanese Restaurant',
#   'location': {'address': '123 Astronaut E S Onizuka St',
#    'lat': 34.049786,
#    'lng': -118.241928,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.049786,
#      'lng': -118.241928}],
#    'distance': 441,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['123 Astronaut E S Onizuka St',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4d4b7105d754a06374d81259',
#     'name': 'Food',
#     'pluralName': 'Food',
#     'shortName': 'Food',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4a52b210f964a520eeb11fe3',
#   'name': 'East Japanese Restaurant',
#   'location': {'address': '329 1st St',
#    'lat': 34.049832,
#    'lng': -118.240224,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.049832,
#      'lng': -118.240224}],
#    'distance': 489,
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['329 1st St', 'Los Angeles, CA', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d111941735',
#     'name': 'Japanese Restaurant',
#     'pluralName': 'Japanese Restaurants',
#     'shortName': 'Japanese',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '5c708ab5aa6c950039227d59',
#   'name': 'Hill Street Bar & Restaurant',
#   'location': {'address': '200 S Hill St',
#    'lat': 34.052738,
#    'lng': -118.247693,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.052738,
#      'lng': -118.247693}],
#    'distance': 466,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['200 S Hill St',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d14e941735',
#     'name': 'American Restaurant',
#     'pluralName': 'American Restaurants',
#     'shortName': 'American',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#      'suffix': '.png'},
#     'primary': True}],
#   'delivery': {'id': '1589615',
#    'url': 'https://www.grubhub.com/restaurant/hill-street-bar--restaurant-200-south-hill-street-los-angeles/1589615?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1589615',
#    'provider': {'name': 'grubhub',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_grubhub_20180129.png'}}},
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4b8a2ff9f964a520596332e3',
#   'name': 'Paraiso Restaurant',
#   'location': {'address': '115 W 3rd St',
#    'lat': 34.049955,
#    'lng': -118.245994,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.049955,
#      'lng': -118.245994},
#     {'label': 'entrance', 'lat': 34.049884, 'lng': -118.246183}],
#    'distance': 511,
#    'postalCode': '90013',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['115 W 3rd St',
#     'Los Angeles, CA 90013',
#     'United States']},
#   'categories': [],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4dd1a37a227159fef239769a',
#   'name': 'Keung Kee B.B.Q. Restaurant',
#   'location': {'address': '420 Ord St',
#    'crossStreet': 'Hill st',
#    'lat': 34.0604362487793,
#    'lng': -118.24009704589844,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.0604362487793,
#      'lng': -118.24009704589844}],
#    'distance': 790,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['420 Ord St (Hill st)',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d145941735',
#     'name': 'Chinese Restaurant',
#     'pluralName': 'Chinese Restaurants',
#     'shortName': 'Chinese',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'delivery': {'id': '2187700',
#    'url': 'https://www.grubhub.com/restaurant/keung-kee-bbq-420-ord-st-los-angeles/2187700?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2187700',
#    'provider': {'name': 'grubhub',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_grubhub_20180129.png'}}},
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '50d36050498ebcf92ba1ecff',
#   'name': 'El Venado Bakery and Restaurant',
#   'location': {'address': '1007 S Alvarado St',
#    'crossStreet': 'Olympic',
#    'lat': 34.051704218127185,
#    'lng': -118.28047795612379,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.051704218127185,
#      'lng': -118.28047795612379}],
#    'distance': 3485,
#    'postalCode': '90006',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['1007 S Alvarado St (Olympic)',
#     'Los Angeles, CA 90006',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1be941735',
#     'name': 'Latin American Restaurant',
#     'pluralName': 'Latin American Restaurants',
#     'shortName': 'Latin American',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#      'suffix': '.png'},
#     'primary': True}],
#   'delivery': {'id': '1912701',
#    'url': 'https://www.grubhub.com/restaurant/el-venado-bakery-and-restaurant-1007-south-alvarado-street-los-angeles/1912701?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1912701',
#    'provider': {'name': 'grubhub',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_grubhub_20180129.png'}}},
#   'venuePage': {'id': '80752779'},
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '55abc10f498e73eddd7ab75d',
#   'name': 'Little Sagion International Restaurant Group Headquarters 小西龚越南美食集团',
#   'location': {'address': 'Los Angeles',
#    'crossStreet': 'United States',
#    'lat': 34.050088,
#    'lng': -118.240379,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.050088,
#      'lng': -118.240379}],
#    'distance': 457,
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['Los Angeles (United States)',
#     'Los Angeles, CA',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d142941735',
#     'name': 'Asian Restaurant',
#     'pluralName': 'Asian Restaurants',
#     'shortName': 'Asian',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4b9d5b02f964a52054a636e3',
#   'name': 'Colima Restaurant',
#   'location': {'address': '400 W Cesar E Chavez Ave',
#    'lat': 34.05858,
#    'lng': -118.24042,
#    'labeledLatLngs': [{'label': 'display', 'lat': 34.05858, 'lng': -118.24042},
#     {'label': 'entrance', 'lat': 34.058523, 'lng': -118.24049}],
#    'distance': 585,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['400 W Cesar E Chavez Ave',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1c1941735',
#     'name': 'Mexican Restaurant',
#     'pluralName': 'Mexican Restaurants',
#     'shortName': 'Mexican',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4d01711b725e60fc040041b9',
#   'name': 'Oiwake Restaurant & Karaoke Bar',
#   'location': {'address': '122 Japanese Village Plaza Mall',
#    'lat': 34.04895545821701,
#    'lng': -118.23994019816385,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.04895545821701,
#      'lng': -118.23994019816385},
#     {'label': 'entrance', 'lat': 34.048914, 'lng': -118.240246}],
#    'distance': 588,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['122 Japanese Village Plaza Mall',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d120941735',
#     'name': 'Karaoke Bar',
#     'pluralName': 'Karaoke Bars',
#     'shortName': 'Karaoke',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/karaoke_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '50ec744819a92ef6c73fbfaa',
#   'name': 'Grouper Social Club at Weiland Brewery Restaurant',
#   'location': {'address': '400 E 1st St',
#    'crossStreet': 'btwn S Alameda St & S Central Ave',
#    'lat': 34.04893112182617,
#    'lng': -118.23892974853516,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.04893112182617,
#      'lng': -118.23892974853516}],
#    'distance': 637,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['400 E 1st St (btwn S Alameda St & S Central Ave)',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d11a941735',
#     'name': 'Other Nightlife',
#     'pluralName': 'Other Nightlife',
#     'shortName': 'Nightlife',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '5780568f498e9934ec69d3b6',
#   'name': 'Los Compadres Restaurant',
#   'location': {'address': '633 N Spring St',
#    'lat': 34.05841827392578,
#    'lng': -118.2387466430664,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.05841827392578,
#      'lng': -118.2387466430664}],
#    'distance': 643,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['633 N Spring St',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1c1941735',
#     'name': 'Mexican Restaurant',
#     'pluralName': 'Mexican Restaurants',
#     'shortName': 'Mexican',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4cdf4668df986ea87a45e116',
#   'name': 'Fred Harvey Restaurant',
#   'location': {'lat': 34.05577711870245,
#    'lng': -118.23664119524993,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.05577711870245,
#      'lng': -118.23664119524993}],
#    'distance': 610,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['Los Angeles, CA 90012', 'United States']},
#   'categories': [],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4c65d89ac2ead13a1a44b280',
#   'name': 'El Delfin Restaurant',
#   'location': {'address': '1800 S Central Ave',
#    'crossStreet': '18th St',
#    'lat': 34.025071171012065,
#    'lng': -118.2498004455827,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.025071171012065,
#      'lng': -118.2498004455827}],
#    'distance': 3251,
#    'postalCode': '90021',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['1800 S Central Ave (18th St)',
#     'Los Angeles, CA 90021',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1c1941735',
#     'name': 'Mexican Restaurant',
#     'pluralName': 'Mexican Restaurants',
#     'shortName': 'Mexican',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#      'suffix': '.png'},
#     'primary': True}],
#   'delivery': {'id': '1917805',
#    'url': 'https://www.grubhub.com/restaurant/el-delfin-restaurant-1800-south-central-avenue-los-angeles/1917805?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1917805',
#    'provider': {'name': 'grubhub',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_grubhub_20180129.png'}}},
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4c37da4ddfb0e21e97a8ada8',
#   'name': "Mandini's Family Restaurant",
#   'location': {'address': '2021 W 3rd St',
#    'crossStreet': 'Alvarado',
#    'lat': 34.063011169433594,
#    'lng': -118.27182006835938,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.063011169433594,
#      'lng': -118.27182006835938}],
#    'distance': 2873,
#    'postalCode': '90057',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['2021 W 3rd St (Alvarado)',
#     'Los Angeles, CA 90057',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d110941735',
#     'name': 'Italian Restaurant',
#     'pluralName': 'Italian Restaurants',
#     'shortName': 'Italian',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4ad930fcf964a520f61821e3',
#   'name': 'Ruen Pair Thai Restaurant',
#   'location': {'address': '5257 Hollywood Blvd',
#    'crossStreet': 'at N Hobart Blvd',
#    'lat': 34.10203547642684,
#    'lng': -118.30560382956727,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.10203547642684,
#      'lng': -118.30560382956727},
#     {'label': 'entrance', 'lat': 34.101873, 'lng': -118.305407}],
#    'distance': 7907,
#    'postalCode': '90027',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['5257 Hollywood Blvd (at N Hobart Blvd)',
#     'Los Angeles, CA 90027',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d149941735',
#     'name': 'Thai Restaurant',
#     'pluralName': 'Thai Restaurants',
#     'shortName': 'Thai',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4df1298522710ce8f79789be',
#   'name': 'Otomisan Japanese Restaurant',
#   'location': {'address': '2506 1/2 E 1st St',
#    'lat': 34.04305659885357,
#    'lng': -118.20838034660254,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.04305659885357,
#      'lng': -118.20838034660254},
#     {'label': 'entrance', 'lat': 34.042975, 'lng': -118.208404}],
#    'distance': 3385,
#    'postalCode': '90033',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['2506 1/2 E 1st St',
#     'Los Angeles, CA 90033',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d111941735',
#     'name': 'Japanese Restaurant',
#     'pluralName': 'Japanese Restaurants',
#     'shortName': 'Japanese',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#      'suffix': '.png'},
#     'primary': True}],
#   'delivery': {'id': '1590474',
#    'url': 'https://www.grubhub.com/restaurant/otomisan-restaurant-2506-east-1st-street-los-angeles/1590474?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1590474',
#    'provider': {'name': 'grubhub',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_grubhub_20180129.png'}}},
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '43ee0ffef964a5205e2f1fe3',
#   'name': 'Astro Family Restaurant',
#   'location': {'address': '2300 Fletcher Dr',
#    'crossStreet': 'at Glendale Blvd',
#    'lat': 34.10460607934933,
#    'lng': -118.25884253377507,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.10460607934933,
#      'lng': -118.25884253377507},
#     {'label': 'entrance', 'lat': 34.104533, 'lng': -118.258831}],
#    'distance': 5858,
#    'postalCode': '90039',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['2300 Fletcher Dr (at Glendale Blvd)',
#     'Los Angeles, CA 90039',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d147941735',
#     'name': 'Diner',
#     'pluralName': 'Diners',
#     'shortName': 'Diner',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#      'suffix': '.png'},
#     'primary': True}],
#   'delivery': {'id': '319398',
#    'url': 'https://www.grubhub.com/restaurant/astro-family-2300-fletcher-dr-los-angeles/319398?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=319398',
#    'provider': {'name': 'grubhub',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_grubhub_20180129.png'}}},
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4f32af4d19836c91c7efafbf',
#   'name': "O'Dom Bang Restaurant",
#   'location': {'address': '648 New High St',
#    'lat': 34.05958938598633,
#    'lng': -118.23826599121094,
#    'labeledLatLngs': [{'label': 'entrance',
#      'lat': 34.059531,
#      'lng': -118.238155},
#     {'label': 'display',
#      'lat': 34.05958938598633,
#      'lng': -118.23826599121094}],
#    'distance': 776,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['648 New High St',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4d4b7105d754a06374d81259',
#     'name': 'Food',
#     'pluralName': 'Food',
#     'shortName': 'Food',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4cd73d702944b1f7585e67ec',
#   'name': 'Hong Kong BBQ Restaurant',
#   'location': {'address': '803 N Broadway',
#    'crossStreet': 'at Alpine St.',
#    'lat': 34.06252029091686,
#    'lng': -118.23824936956532,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.06252029091686,
#      'lng': -118.23824936956532},
#     {'label': 'entrance', 'lat': 34.062541, 'lng': -118.238351}],
#    'distance': 1067,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['803 N Broadway (at Alpine St.)',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d145941735',
#     'name': 'Chinese Restaurant',
#     'pluralName': 'Chinese Restaurants',
#     'shortName': 'Chinese',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'delivery': {'id': '1645630',
#    'url': 'https://www.grubhub.com/restaurant/hong-kong-bbq-803-north-broadway-los-angeles/1645630?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1645630',
#    'provider': {'name': 'grubhub',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_grubhub_20180129.png'}}},
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4b6c7385f964a520313b2ce3',
#   'name': 'Almas restaurant',
#   'location': {'address': '1403 Hooper Ave',
#    'crossStreet': 'btw 14th street',
#    'lat': 34.02644434065198,
#    'lng': -118.24325425883144,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.02644434065198,
#      'lng': -118.24325425883144}],
#    'distance': 3033,
#    'postalCode': '90021',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['1403 Hooper Ave (btw 14th street)',
#     'Los Angeles, CA 90021',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1c1941735',
#     'name': 'Mexican Restaurant',
#     'pluralName': 'Mexican Restaurants',
#     'shortName': 'Mexican',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4c00d9439cf52d7f636714e7',
#   'name': 'Hae Jang Chon Korean BBQ Restaurant',
#   'location': {'address': '3821 West 6th Street',
#    'lat': 34.0638885,
#    'lng': -118.3060754,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.0638885,
#      'lng': -118.3060754}],
#    'distance': 5947,
#    'postalCode': '90020',
#    'cc': 'US',
#    'neighborhood': 'Wilshire Center - Koreatown',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['3821 West 6th Street',
#     'Los Angeles, CA 90020',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d113941735',
#     'name': 'Korean Restaurant',
#     'pluralName': 'Korean Restaurants',
#     'shortName': 'Korean',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#      'suffix': '.png'},
#     'primary': True}],
#   'delivery': {'id': '1591634',
#    'url': 'https://www.grubhub.com/restaurant/hae-jang-chon-korean-bbq-restaurant-3821-west-6th-street-los-angeles/1591634?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1591634',
#    'provider': {'name': 'grubhub',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_grubhub_20180129.png'}}},
#   'venuePage': {'id': '79599419'},
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4b3c2d94f964a520a38225e3',
#   'name': 'Hop Woo BBQ Seafood Restaurant',
#   'location': {'address': '845 N Broadway',
#    'lat': 34.06364617250033,
#    'lng': -118.23766989273867,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.06364617250033,
#      'lng': -118.23766989273867},
#     {'label': 'entrance', 'lat': 34.063632, 'lng': -118.237803}],
#    'distance': 1203,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['845 N Broadway',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d145941735',
#     'name': 'Chinese Restaurant',
#     'pluralName': 'Chinese Restaurants',
#     'shortName': 'Chinese',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'delivery': {'id': '314482',
#    'url': 'https://www.grubhub.com/restaurant/hop-woo-bbq-and-seafood-chinese-restaurant-845-n-broadway-blvd-los-angeles/314482?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=314482',
#    'provider': {'name': 'grubhub',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_grubhub_20180129.png'}}},
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4fc40809e4b012f50039ddd1',
#   'name': 'Friendly Seafood Restaurant',
#   'location': {'lat': 34.06130599975586,
#    'lng': -118.23933410644531,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.06130599975586,
#      'lng': -118.23933410644531}],
#    'distance': 904,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['Los Angeles, CA 90012', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d145941735',
#     'name': 'Chinese Restaurant',
#     'pluralName': 'Chinese Restaurants',
#     'shortName': 'Chinese',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4f322ef319836c91c7be56a2',
#   'name': 'Viet Huong Restaurant',
#   'location': {'address': '727 N Broadway',
#    'lat': 34.06130599975586,
#    'lng': -118.23933410644531,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.06130599975586,
#      'lng': -118.23933410644531}],
#    'distance': 904,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['727 N Broadway',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4d4b7105d754a06374d81259',
#     'name': 'Food',
#     'pluralName': 'Food',
#     'shortName': 'Food',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4ef7aa39be7bb4784dd3d06f',
#   'name': 'thanh vi restaurant',
#   'location': {'address': '422 Ord St',
#    'lat': 34.06077009373006,
#    'lng': -118.24026185059148,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.06077009373006,
#      'lng': -118.24026185059148}],
#    'distance': 821,
#    'postalCode': '90012',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['422 Ord St',
#     'Los Angeles, CA 90012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d14a941735',
#     'name': 'Vietnamese Restaurant',
#     'pluralName': 'Vietnamese Restaurants',
#     'shortName': 'Vietnamese',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4f32699719836c91c7d55134',
#   'name': 'Tai Pan Restaurant',
#   'location': {'address': '330 S Hope St',
#    'lat': 34.05334,
#    'lng': -118.252679,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.05334,
#      'lng': -118.252679}],
#    'distance': 915,
#    'postalCode': '90071',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['330 S Hope St',
#     'Los Angeles, CA 90071',
#     'United States']},
#   'categories': [{'id': '4d4b7105d754a06374d81259',
#     'name': 'Food',
#     'pluralName': 'Food',
#     'shortName': 'Food',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False},
#  {'id': '4d01be9e3be26dcbd88374e4',
#   'name': 'Coronado’s Mexican Restaurant & Bar',
#   'location': {'address': '212 W 5th St',
#    'crossStreet': 'at Spring St',
#    'lat': 34.04768646419671,
#    'lng': -118.25002199566127,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 34.04768646419671,
#      'lng': -118.25002199566127},
#     {'label': 'entrance', 'lat': 34.04756, 'lng': -118.250041}],
#    'distance': 945,
#    'postalCode': '90013',
#    'cc': 'US',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'country': 'United States',
#    'formattedAddress': ['212 W 5th St (at Spring St)',
#     'Los Angeles, CA 90013',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1c1941735',
#     'name': 'Mexican Restaurant',
#     'pluralName': 'Mexican Restaurants',
#     'shortName': 'Mexican',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1597820453',
#   'hasPerk': False}]

# %% [markdown]
# ### Clean the json and structure it into a *pandas* dataframe.

# %% [markdown]
# Build a function to extract the category of the venue.

# %%
# function that extracts the category of the venue
def get_category_type(row):
    if len(row) == 0:
        return None
    else:
        return row[0]['name']

# %% [markdown]
# #### Clean the json and structure it into a pandas dataframe.

# %%
## Process JSON and convert it to a clean dataframe
venues_df = json_normalize(venues) # flatten JSON
# filter columns
filtered_columns = ['name', 'categories', 'location.address', 'location.distance', 'location.postalCode','location.lat', 'location.lng']
venues_df = venues_df[filtered_columns]
# filter the category for each row
venues_df['categories'] = venues_df['categories'].apply(lambda x: get_category_type(x))
# clean columns
venues_df.columns = [col.split('.')[-1] for col in venues_df.columns]
venues_df
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                                  name  \
# 0                                    Traxx Restaurant
# 1                        Mayflower Seafood Restaurant
# 2                                Noe Restaurant & Bar
# 3        24/7 Restaurant at The Standard, Downtown LA
# 4                                 Restaurant Guerrero
# 5                       Full House Seafood Restaurant
# 6                                Yang Chow Restaurant
# 7                                   Amante Restaurant
# 8                                  Trimana Restaurant
# 9                                  Wok Inn Restaurant
# 10                                 Restaurant Atitlan
# 11                            Doña Vicky's Restaurant
# 12                          Matsu Japanese Restaurant
# 13                                   Lelit Restaurant
# 14        Gill’s Indian Restaurant| ORDER FOOD ONLINE
# 15                          La Guadalupana Restaurant
# 16                                 Won Kok Restaurant
# 17                                   Rikyu Restaurant
# 18                                   Restaurant Spain
# 19                             Taix French Restaurant
# 20                              360 Restaurant Design
# 21                                  Market Restaurant
# 22  Japanese Restaurant Association of Southern Ca...
# 23                        Daisuke Japanese Restaurant
# 24                           East Japanese Restaurant
# 25                       Hill Street Bar & Restaurant
# 26                                 Paraiso Restaurant
# 27                        Keung Kee B.B.Q. Restaurant
# 28                    El Venado Bakery and Restaurant
# 29  Little Sagion International Restaurant Group H...
# 30                                  Colima Restaurant
# 31                    Oiwake Restaurant & Karaoke Bar
# 32  Grouper Social Club at Weiland Brewery Restaurant
# 33                           Los Compadres Restaurant
# 34                             Fred Harvey Restaurant
# 35                               El Delfin Restaurant
# 36                        Mandini's Family Restaurant
# 37                          Ruen Pair Thai Restaurant
# 38                       Otomisan Japanese Restaurant
# 39                            Astro Family Restaurant
# 40                              O'Dom Bang Restaurant
# 41                           Hong Kong BBQ Restaurant
# 42                                   Almas restaurant
# 43                Hae Jang Chon Korean BBQ Restaurant
# 44                     Hop Woo BBQ Seafood Restaurant
# 45                        Friendly Seafood Restaurant
# 46                              Viet Huong Restaurant
# 47                                thanh vi restaurant
# 48                                 Tai Pan Restaurant
# 49                Coronado’s Mexican Restaurant & Bar
#
#                     categories                            address  distance  \
# 0      New American Restaurant                   800 N Alameda St       669
# 1           Seafood Restaurant                    679 N Spring St       782
# 2            French Restaurant                     251 S Olive St       771
# 3          American Restaurant                    550 S Flower St      1344
# 4           Mexican Restaurant                       320 W 8th St      1590
# 5           Chinese Restaurant                      963 N Hill St      1457
# 6           Chinese Restaurant                     819 N Broadway      1115
# 7           Italian Restaurant                       123 E 9th St      1761
# 8                  Salad Place                      633 W 5th St.      1171
# 9             Asian Restaurant       201 N Los Angeles St Ste 102       116
# 10   Latin American Restaurant                      1614 W 6th St      2529
# 11          Mexican Restaurant                      1263 W 2nd St      1563
# 12            Sushi Restaurant                   1267 W Temple St      1739
# 13    Mediterranean Restaurant                       109 E 9th St      1748
# 14           Indian Restaurant                    838 S Grand Ave      1761
# 15          Mexican Restaurant                                Idk       182
# 16          Chinese Restaurant                      210 Alpine St      1040
# 17         Japanese Restaurant       123 Astronaut E S Onizuka St       327
# 18          Spanish Restaurant                 1866 Glendale Blvd      4271
# 19           French Restaurant                 1911 W Sunset Blvd      3223
# 20  Construction & Landscaping  8055 Manchester Avenue Suite 230A       364
# 21                  Restaurant               862 S Los Angeles St      1761
# 22         Japanese Restaurant                       324 E 1st St       437
# 23                        Food       123 Astronaut E S Onizuka St       441
# 24         Japanese Restaurant                         329 1st St       489
# 25         American Restaurant                      200 S Hill St       466
# 26                        None                       115 W 3rd St       511
# 27          Chinese Restaurant                         420 Ord St       790
# 28   Latin American Restaurant                 1007 S Alvarado St      3485
# 29            Asian Restaurant                        Los Angeles       457
# 30          Mexican Restaurant           400 W Cesar E Chavez Ave       585
# 31                 Karaoke Bar    122 Japanese Village Plaza Mall       588
# 32             Other Nightlife                       400 E 1st St       637
# 33          Mexican Restaurant                    633 N Spring St       643
# 34                        None                                NaN       610
# 35          Mexican Restaurant                 1800 S Central Ave      3251
# 36          Italian Restaurant                      2021 W 3rd St      2873
# 37             Thai Restaurant                5257 Hollywood Blvd      7907
# 38         Japanese Restaurant                  2506 1/2 E 1st St      3385
# 39                       Diner                   2300 Fletcher Dr      5858
# 40                        Food                    648 New High St       776
# 41          Chinese Restaurant                     803 N Broadway      1067
# 42          Mexican Restaurant                    1403 Hooper Ave      3033
# 43           Korean Restaurant               3821 West 6th Street      5947
# 44          Chinese Restaurant                     845 N Broadway      1203
# 45          Chinese Restaurant                                NaN       904
# 46                        Food                     727 N Broadway       904
# 47       Vietnamese Restaurant                         422 Ord St       821
# 48                        Food                      330 S Hope St       915
# 49          Mexican Restaurant                       212 W 5th St       945
#
#    postalCode        lat         lng
# 0       90012  34.056232 -118.236183
# 1       90012  34.059582 -118.238129
# 2       90012  34.052290 -118.250963
# 3       90071  34.049743 -118.256548
# 4       90014  34.044159 -118.255615
# 5       90012  34.066155 -118.237916
# 6       90012  34.062926 -118.238059
# 7       90015  34.041191 -118.254481
# 8       90071  34.050811 -118.254983
# 9       90012  34.054317 -118.241752
# 10      90017  34.057095 -118.269879
# 11      90026  34.060190 -118.257793
# 12      90026  34.066298 -118.253917
# 13      90015  34.041388 -118.254555
# 14      90017  34.044647 -118.258433
# 15      90012  34.052236 -118.243683
# 16      90012  34.061958 -118.237509
# 17      90012  34.050814 -118.242030
# 18      90026  34.089681 -118.258838
# 19      90026  34.078103 -118.261575
# 20      90045  34.051824 -118.246011
# 21      90014  34.040842 -118.253910
# 22      90012  34.050188 -118.240606
# 23      90012  34.049786 -118.241928
# 24        NaN  34.049832 -118.240224
# 25      90012  34.052738 -118.247693
# 26      90013  34.049955 -118.245994
# 27      90012  34.060436 -118.240097
# 28      90006  34.051704 -118.280478
# 29        NaN  34.050088 -118.240379
# 30      90012  34.058580 -118.240420
# 31      90012  34.048955 -118.239940
# 32      90012  34.048931 -118.238930
# 33      90012  34.058418 -118.238747
# 34      90012  34.055777 -118.236641
# 35      90021  34.025071 -118.249800
# 36      90057  34.063011 -118.271820
# 37      90027  34.102035 -118.305604
# 38      90033  34.043057 -118.208380
# 39      90039  34.104606 -118.258843
# 40      90012  34.059589 -118.238266
# 41      90012  34.062520 -118.238249
# 42      90021  34.026444 -118.243254
# 43      90020  34.063888 -118.306075
# 44      90012  34.063646 -118.237670
# 45      90012  34.061306 -118.239334
# 46      90012  34.061306 -118.239334
# 47      90012  34.060770 -118.240262
# 48      90071  34.053340 -118.252679
# 49      90013  34.047686 -118.250022

# %% [markdown]
# #### Get only venues that 'categories' belong to 'restaurant'.

# %%
# get only venues that 'categories' belong to 'restaurant' 
restaurants = venues_df[venues_df['categories'].astype(str).str.contains('Restaurant')].reset_index(drop=True)
restaurants
# Out:
#                                                  name  \
# 0                                    Traxx Restaurant
# 1                        Mayflower Seafood Restaurant
# 2                                Noe Restaurant & Bar
# 3        24/7 Restaurant at The Standard, Downtown LA
# 4                                 Restaurant Guerrero
# 5                       Full House Seafood Restaurant
# 6                                Yang Chow Restaurant
# 7                                   Amante Restaurant
# 8                                  Wok Inn Restaurant
# 9                                  Restaurant Atitlan
# 10                            Doña Vicky's Restaurant
# 11                          Matsu Japanese Restaurant
# 12                                   Lelit Restaurant
# 13        Gill’s Indian Restaurant| ORDER FOOD ONLINE
# 14                          La Guadalupana Restaurant
# 15                                 Won Kok Restaurant
# 16                                   Rikyu Restaurant
# 17                                   Restaurant Spain
# 18                             Taix French Restaurant
# 19                                  Market Restaurant
# 20  Japanese Restaurant Association of Southern Ca...
# 21                           East Japanese Restaurant
# 22                       Hill Street Bar & Restaurant
# 23                        Keung Kee B.B.Q. Restaurant
# 24                    El Venado Bakery and Restaurant
# 25  Little Sagion International Restaurant Group H...
# 26                                  Colima Restaurant
# 27                           Los Compadres Restaurant
# 28                               El Delfin Restaurant
# 29                        Mandini's Family Restaurant
# 30                          Ruen Pair Thai Restaurant
# 31                       Otomisan Japanese Restaurant
# 32                           Hong Kong BBQ Restaurant
# 33                                   Almas restaurant
# 34                Hae Jang Chon Korean BBQ Restaurant
# 35                     Hop Woo BBQ Seafood Restaurant
# 36                        Friendly Seafood Restaurant
# 37                                thanh vi restaurant
# 38                Coronado’s Mexican Restaurant & Bar
#
#                    categories                       address  distance  \
# 0     New American Restaurant              800 N Alameda St       669
# 1          Seafood Restaurant               679 N Spring St       782
# 2           French Restaurant                251 S Olive St       771
# 3         American Restaurant               550 S Flower St      1344
# 4          Mexican Restaurant                  320 W 8th St      1590
# 5          Chinese Restaurant                 963 N Hill St      1457
# 6          Chinese Restaurant                819 N Broadway      1115
# 7          Italian Restaurant                  123 E 9th St      1761
# 8            Asian Restaurant  201 N Los Angeles St Ste 102       116
# 9   Latin American Restaurant                 1614 W 6th St      2529
# 10         Mexican Restaurant                 1263 W 2nd St      1563
# 11           Sushi Restaurant              1267 W Temple St      1739
# 12   Mediterranean Restaurant                  109 E 9th St      1748
# 13          Indian Restaurant               838 S Grand Ave      1761
# 14         Mexican Restaurant                           Idk       182
# 15         Chinese Restaurant                 210 Alpine St      1040
# 16        Japanese Restaurant  123 Astronaut E S Onizuka St       327
# 17         Spanish Restaurant            1866 Glendale Blvd      4271
# 18          French Restaurant            1911 W Sunset Blvd      3223
# 19                 Restaurant          862 S Los Angeles St      1761
# 20        Japanese Restaurant                  324 E 1st St       437
# 21        Japanese Restaurant                    329 1st St       489
# 22        American Restaurant                 200 S Hill St       466
# 23         Chinese Restaurant                    420 Ord St       790
# 24  Latin American Restaurant            1007 S Alvarado St      3485
# 25           Asian Restaurant                   Los Angeles       457
# 26         Mexican Restaurant      400 W Cesar E Chavez Ave       585
# 27         Mexican Restaurant               633 N Spring St       643
# 28         Mexican Restaurant            1800 S Central Ave      3251
# 29         Italian Restaurant                 2021 W 3rd St      2873
# 30            Thai Restaurant           5257 Hollywood Blvd      7907
# 31        Japanese Restaurant             2506 1/2 E 1st St      3385
# 32         Chinese Restaurant                803 N Broadway      1067
# 33         Mexican Restaurant               1403 Hooper Ave      3033
# 34          Korean Restaurant          3821 West 6th Street      5947
# 35         Chinese Restaurant                845 N Broadway      1203
# 36         Chinese Restaurant                           NaN       904
# 37      Vietnamese Restaurant                    422 Ord St       821
# 38         Mexican Restaurant                  212 W 5th St       945
#
#    postalCode        lat         lng
# 0       90012  34.056232 -118.236183
# 1       90012  34.059582 -118.238129
# 2       90012  34.052290 -118.250963
# 3       90071  34.049743 -118.256548
# 4       90014  34.044159 -118.255615
# 5       90012  34.066155 -118.237916
# 6       90012  34.062926 -118.238059
# 7       90015  34.041191 -118.254481
# 8       90012  34.054317 -118.241752
# 9       90017  34.057095 -118.269879
# 10      90026  34.060190 -118.257793
# 11      90026  34.066298 -118.253917
# 12      90015  34.041388 -118.254555
# 13      90017  34.044647 -118.258433
# 14      90012  34.052236 -118.243683
# 15      90012  34.061958 -118.237509
# 16      90012  34.050814 -118.242030
# 17      90026  34.089681 -118.258838
# 18      90026  34.078103 -118.261575
# 19      90014  34.040842 -118.253910
# 20      90012  34.050188 -118.240606
# 21        NaN  34.049832 -118.240224
# 22      90012  34.052738 -118.247693
# 23      90012  34.060436 -118.240097
# 24      90006  34.051704 -118.280478
# 25        NaN  34.050088 -118.240379
# 26      90012  34.058580 -118.240420
# 27      90012  34.058418 -118.238747
# 28      90021  34.025071 -118.249800
# 29      90057  34.063011 -118.271820
# 30      90027  34.102035 -118.305604
# 31      90033  34.043057 -118.208380
# 32      90012  34.062520 -118.238249
# 33      90021  34.026444 -118.243254
# 34      90020  34.063888 -118.306075
# 35      90012  34.063646 -118.237670
# 36      90012  34.061306 -118.239334
# 37      90012  34.060770 -118.240262
# 38      90013  34.047686 -118.250022

# %% [markdown]
# ### Get all Chinese restaurants information.
#   Now we've got all the restaurants information around a location, it's time to specify categories to our desired restaurants.
# #### Check 'categories' to see how many unique restaurant categories we have around this location.

# %%
# get unique 'categories'
restaurants['categories'].unique()
# Out:
# array(['New American Restaurant', 'Seafood Restaurant',
#        'French Restaurant', 'American Restaurant', 'Mexican Restaurant',
#        'Chinese Restaurant', 'Italian Restaurant', 'Asian Restaurant',
#        'Latin American Restaurant', 'Sushi Restaurant',
#        'Mediterranean Restaurant', 'Indian Restaurant',
#        'Japanese Restaurant', 'Spanish Restaurant', 'Restaurant',
#        'Thai Restaurant', 'Korean Restaurant', 'Vietnamese Restaurant'],
#       dtype=object)

# %% [markdown]
#   Apparently, there's a big chance 'Asian Restaurant' will serve chinese food, but it could also be Japanese or Korean restaurant. For this project, I'll keep this category.
#   Running above code several times on different locations, I've also found some other facts, such as 'Dim Sum Restaurant', 'Hotpot Restaurant', 'Peking Duck Restaurant', 'Dumpling Restaurant', etc. Therefore, those catergories will be added to the **chinese_restaurants_list** in the following code cell.

# %% [markdown]
#   In order to be more accurate, some other chinese cuisine mentioned in **List of Chinese cuisine**: https://en.wikipedia.org/wiki/Chinese_cuisine will also be added to **chinese_restaurant_list**. I've added the eight major cuisine and some other categories based on my personal perference from list below:
# #### The eight major traditions of Chinese cuisine:
# Shandong cuisine, Sichuan cuisine, Cantonese cuisine, Fujian cuisine, Jiangsu cuisine, Zhejiang cuisine, Hunan cuisine, Anhui cuisine
# #### Other traditions in Chinese cuisine:
# Beijing cuisine, Chinese imperial cuisine, Guizhou cuisine, Henan cuisine, Huaiyang cuisine, Hubei cuisine, Jiangxi cuisine, Shaanxi cuisine, Shanghai cuisine, Shanxi cuisine, Teochew cuisine

# %% [markdown]
# #### Create a list to include other categories that didn't list as 'Chinese Restaurant' in Foursquare.
# Note: You can modify **chinese_restaurants_list** to include more/less categories, or even create your own list, such as japanese_restaurants_list, korean_restaurants_list, indian_restaurants_list, italian_restaurants_list, etc.

# %%
# create a Chinese restaurant list based on my perference.
chinese_restaurants_list = ['Dim Sum Restaurant', 
                            'Szechuan Restaurant',
                            'Chinese Restaurant', 
                            'Cantonese Restaurant', 
                            'Asian Restaurant',  # this category may include other Asian Restaurant, such as Japanese Restaurant, Korean Restaurant, etc.
                            'Hotpot Restaurant',
                            'Peking Duck Restaurant',
                            'Shanxi Restaurant',
                            'Beijing Restaurant',
                            'Xinjiang Restaurant',
                            'Hong Kong Restaurant',
                            'Dumpling Restaurant',
                            'Yunnan Restaurant',
                            'Shandong Restaurant',
                            'Fujian Restaurant', 
                            'Jiangsu Restaurant',
                            'Zhejiang Restaurant',
                            'Hunan Restaurant',
                            'Anhui Restaurant',
                           ] # this can be changed according to personal perference, just be sure to add ' Restaurant' as suffix
chinese_restaurants = restaurants[restaurants['categories'].isin(chinese_restaurants_list)].reset_index(drop=True)
chinese_restaurants
# Out:
#                                                 name          categories  \
# 0                      Full House Seafood Restaurant  Chinese Restaurant
# 1                               Yang Chow Restaurant  Chinese Restaurant
# 2                                 Wok Inn Restaurant    Asian Restaurant
# 3                                 Won Kok Restaurant  Chinese Restaurant
# 4                        Keung Kee B.B.Q. Restaurant  Chinese Restaurant
# 5  Little Sagion International Restaurant Group H...    Asian Restaurant
# 6                           Hong Kong BBQ Restaurant  Chinese Restaurant
# 7                     Hop Woo BBQ Seafood Restaurant  Chinese Restaurant
# 8                        Friendly Seafood Restaurant  Chinese Restaurant
#
#                         address  distance postalCode        lat         lng
# 0                 963 N Hill St      1457      90012  34.066155 -118.237916
# 1                819 N Broadway      1115      90012  34.062926 -118.238059
# 2  201 N Los Angeles St Ste 102       116      90012  34.054317 -118.241752
# 3                 210 Alpine St      1040      90012  34.061958 -118.237509
# 4                    420 Ord St       790      90012  34.060436 -118.240097
# 5                   Los Angeles       457        NaN  34.050088 -118.240379
# 6                803 N Broadway      1067      90012  34.062520 -118.238249
# 7                845 N Broadway      1203      90012  34.063646 -118.237670
# 8                           NaN       904      90012  34.061306 -118.239334

# %% [markdown]
# #### Replace NaN value in 'postalCode' and 'address' columns.
# When testing the code on some location, such as 'Los Angeles, CA', some **NaN value** shows up in postalCode or address. Those NaN value will be filled by using Geopy library.

# %%
# create a new column 'lat_lng'
chinese_restaurants['lat'] = chinese_restaurants['lat'].apply(lambda x: '%.6f' % x)
chinese_restaurants['lng'] = chinese_restaurants['lng'].apply(lambda x: '%.6f' % x)
chinese_restaurants['lat_lng'] = chinese_restaurants['lat'].astype(str) + ', ' + chinese_restaurants['lng'].astype(str)
chinese_restaurants.head()
# Out:
#                             name          categories  \
# 0  Full House Seafood Restaurant  Chinese Restaurant
# 1           Yang Chow Restaurant  Chinese Restaurant
# 2             Wok Inn Restaurant    Asian Restaurant
# 3             Won Kok Restaurant  Chinese Restaurant
# 4    Keung Kee B.B.Q. Restaurant  Chinese Restaurant
#
#                         address  distance postalCode        lat          lng  \
# 0                 963 N Hill St      1457      90012  34.066155  -118.237916
# 1                819 N Broadway      1115      90012  34.062926  -118.238059
# 2  201 N Los Angeles St Ste 102       116      90012  34.054317  -118.241752
# 3                 210 Alpine St      1040      90012  34.061958  -118.237509
# 4                    420 Ord St       790      90012  34.060436  -118.240097
#
#                   lat_lng
# 0  34.066155, -118.237916
# 1  34.062926, -118.238059
# 2  34.054317, -118.241752
# 3  34.061958, -118.237509
# 4  34.060436, -118.240097

# %% [markdown]
# Build functions to get postalCode or address.

# %%
# build a function to get postalCode for restaurant if none exists.
def get_postcode(row):
    ind = row['lat_lng']
    row['postalCode'] = str(row['postalCode'])
    if row['postalCode'] == "nan":
        postcode = geolocator.reverse(ind).address.split(',')[-2]
        return postcode[:7]
    else:
        return row['postalCode']

# %%
# build a function to get address for restaurant if none exists.
def get_address(row):
    ind = row['lat_lng']
    row['address'] = str(row['address'])
    if row['address'] == "nan":
        address = geolocator.reverse(ind).address.split(',')[0] + geolocator.reverse(ind).address.split(',')[1]
        return address
    else:
        return row['address']

# %% [markdown]
# Apply functions to replace NaN value in 'postalCode' and 'address'.

# %%
# apply functions
chinese_restaurants['postalCode'] = chinese_restaurants.apply(lambda x: get_postcode(x), axis=1)
chinese_restaurants['address'] = chinese_restaurants.apply(lambda x: get_address(x), axis=1)
chinese_restaurants
# Out:
#                                                 name          categories  \
# 0                      Full House Seafood Restaurant  Chinese Restaurant
# 1                               Yang Chow Restaurant  Chinese Restaurant
# 2                                 Wok Inn Restaurant    Asian Restaurant
# 3                                 Won Kok Restaurant  Chinese Restaurant
# 4                        Keung Kee B.B.Q. Restaurant  Chinese Restaurant
# 5  Little Sagion International Restaurant Group H...    Asian Restaurant
# 6                           Hong Kong BBQ Restaurant  Chinese Restaurant
# 7                     Hop Woo BBQ Seafood Restaurant  Chinese Restaurant
# 8                        Friendly Seafood Restaurant  Chinese Restaurant
#
#                             address  distance postalCode        lat  \
# 0                     963 N Hill St      1457      90012  34.066155
# 1                    819 N Broadway      1115      90012  34.062926
# 2      201 N Los Angeles St Ste 102       116      90012  34.054317
# 3                     210 Alpine St      1040      90012  34.061958
# 4                        420 Ord St       790      90012  34.060436
# 5                       Los Angeles       457      90013  34.050088
# 6                    803 N Broadway      1067      90012  34.062520
# 7                    845 N Broadway      1203      90012  34.063646
# 8  Far East Plaza North Hill Street       904      90012  34.061306
#
#            lng                 lat_lng
# 0  -118.237916  34.066155, -118.237916
# 1  -118.238059  34.062926, -118.238059
# 2  -118.241752  34.054317, -118.241752
# 3  -118.237509  34.061958, -118.237509
# 4  -118.240097  34.060436, -118.240097
# 5  -118.240379  34.050088, -118.240379
# 6  -118.238249  34.062520, -118.238249
# 7  -118.237670  34.063646, -118.237670
# 8  -118.239334  34.061306, -118.239334

# %% [markdown]
# #### Select columns most related to audience.

# %%
# Drop 'lat', 'lng', 'lat_lng' columns.
chinese_restaurants_display = chinese_restaurants.drop(columns = ['lat', 'lng', 'lat_lng'])
chinese_restaurants_display
# Out:
#                                                 name          categories  \
# 0                      Full House Seafood Restaurant  Chinese Restaurant
# 1                               Yang Chow Restaurant  Chinese Restaurant
# 2                                 Wok Inn Restaurant    Asian Restaurant
# 3                                 Won Kok Restaurant  Chinese Restaurant
# 4                        Keung Kee B.B.Q. Restaurant  Chinese Restaurant
# 5  Little Sagion International Restaurant Group H...    Asian Restaurant
# 6                           Hong Kong BBQ Restaurant  Chinese Restaurant
# 7                     Hop Woo BBQ Seafood Restaurant  Chinese Restaurant
# 8                        Friendly Seafood Restaurant  Chinese Restaurant
#
#                             address  distance postalCode
# 0                     963 N Hill St      1457      90012
# 1                    819 N Broadway      1115      90012
# 2      201 N Los Angeles St Ste 102       116      90012
# 3                     210 Alpine St      1040      90012
# 4                        420 Ord St       790      90012
# 5                       Los Angeles       457      90013
# 6                    803 N Broadway      1067      90012
# 7                    845 N Broadway      1203      90012
# 8  Far East Plaza North Hill Street       904      90012

# %% [markdown]
#   Now, we've got all the Chinese restaurants information for one location, 'Los Angeles, CA' for now.
#   But, I've tested it on several other locations, such as 'New York city, NY', 'Shanghai, China', 'London, UK', 'Tokyo, Japan', etc.
#   I'll display them in the **Results section**.

# %% [markdown]
# ### Create a map of restaurants with name superimposed on top.

# %% [markdown]
# Import libraries

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
#!conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library
print("Libraries imported.")
# Out:
# Libraries imported.

# %% [markdown]
# #### Create map of restaurants.

# %%
# create map of restaurants using latitude and longitude values
map_restaurants = folium.Map(location=[latitude, longitude], zoom_start=15)

# add markers to map
for lat, lng, label in zip(chinese_restaurants['lat'].astype(float), chinese_restaurants['lng'].astype(float), chinese_restaurants['name']):
    label = label.split(' (')[0]
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker([lat, lng], radius=5, popup=label, color='blue', fill=True, fill_color='#3186cc', fill_opacity=0.7, parse_html=False).add_to(map_restaurants)  
map_restaurants
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# This 'Los Angeles,CA' Chinese restaurants map will not show up in Github, but you can check it out in **Results section**.
#
# Map of other locations will also be displayed in **Results section**.

# %% [markdown]
# ## Results section
#   Here's the testing location list:
#   Bangkok, Thailand
#   Hong Kong, China
#   London, United Kingdom
#   Los Angeles, CA
#   New York city, NY
#   Paris, France
#   Seattle, WA
#   Shanghai, China
#   Shenzhen, China
#   Singapore, Singapore
#   Tokyo, Japan
# ### Chinese Restaurants information table

# %% [markdown]
# Bangkok, Thailand
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/Bangkok%2C%20Thailand%20-%20table.png "Bangkok, Thailand - table")

# %% [markdown]
# Hong Kong, China
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/Hong%20Kong%2C%20China%20-%20table.png "Hong Kong, China - table")

# %% [markdown]
# London, United Kingdom
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/London%2C%20UK%20-%20table.png "London, United Kingdom - table")

# %% [markdown]
# Los Angeles, CA
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/Los%20Angeles%2C%20CA%20-%20table.png "Los Angeles, CA - table")

# %% [markdown]
# New York city, NY
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/New%20York%20city%2C%20NY%20-%20table.png "New York city, NY - table")

# %% [markdown]
# Paris, France
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/Paris%2C%20France%20-%20table.png "Paris, France - table")

# %% [markdown]
# Seattle, WA
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/Seattle%2C%20WA%20-%20table.png "Seattle, WA - table")

# %% [markdown]
# Shanghai, China
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/Shanghai%2C%20China%20-%20table.png "Shanghai, China - table")

# %% [markdown]
# Shenzhen, China
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/Shenzhen%2C%20China%20-%20table.png "Shenzhen, China - table")

# %% [markdown]
# Singapore, Singapore
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/Singapore%2C%20Singapore%20-%20table.png "Singapore, Singapore - table")

# %% [markdown]
# Tokyo, Japan
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/Tokyo%2C%20Japan%20-%20table.png "Tokyo, Japan - table")

# %% [markdown]
# #### Running the code from this project, we got some clean Chinese restaurants information dataframe, showing restaurants' name, categories, address, distance and postalCode.
# ### Chinese Restaurants Mapping

# %% [markdown]
# Bangkok, Thailand
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/Bangkok%2C%20Thailand%20-%20map.png "Bangkok, Thailand - map")

# %% [markdown]
# Hong Kong, China
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/Hong%20Kong%2C%20China%20-%20map.png "Hong Kong, China - map")

# %% [markdown]
# London, United Kingdom
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/London%2C%20UK%20-%20map.png "London, United Kingdom - map")

# %% [markdown]
# Los Angeles, CA
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/Los%20Angeles%2C%20CA%20-%20map.png "Los Angeles, CA - map")

# %% [markdown]
# New York city, NY
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/New%20York%20city%2C%20NY%20-%20map.png "New York city, NY - map")

# %% [markdown]
# Paris, France
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/Paris%2C%20France%20-%20map.png "Paris, France - map")

# %% [markdown]
# Seattle, WA
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/Seattle%2C%20WA%20-%20map.png "Seattle, WA - map")

# %% [markdown]
# Shanghai, China
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/Shanghai%2C%20China%20-%20map.png "Shanghai, China - map")

# %% [markdown]
# Shenzhen, China
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/Shenzhen%2C%20China%20-%20map.png "Shenzhen, China - map")

# %% [markdown]
# Singapore, Singapore
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/Singapore%2C%20Singapore%20-%20map.png "Singapore, Singapore - map")

# %% [markdown]
# Tokyo, Japan
# ![alt text](https://raw.githubusercontent.com/Faye0924/Coursera_Capstone/master/Capstone%20Project%20-%20Result%20tables%20%26%20maps/Tokyo%2C%20Japan%20-%20map.png "Tokyo, Japan - map")

# %% [markdown]
# #### Running the code from this project, we were also able to display searching location's map with nearby Chinese restaurants' name superimposed on top.

# %% [markdown]
# ## Discussion section
#
#   For the testing locatons, more US and China locations are selected because:
#   US is where we live, also the starting point for this project, and I wanted to make sure this project at least works in US;
#   China, apparently should have more Chinese restaurants categories, as you can see, only Shanghai shows "Yunnan Restaurant" category, that why I decided to include **The eight major traditions of Chinese cuisine** into my **chinese_restaurants_list**.
#
#   In the dataframe 'name' and 'address' columns, I kept the foreign language, because it might be useful when traveling. However, Folium mapping didn't display foreign language correctly, and it beyonded my ability to fix that for now, so I could only keep the english name in the map.
#
#   This project gives a clear table showing restaurants' name, categories, address, distance and postalCode around a certain location; also the restaurants' name superimposed on a neighborhood map.
#
#   Also, this project can be modified to search for other restaurant categories. All you have to do is to modify the **chinese_restaurants_list** to your preferred categories, just be sure to follow the comment instruction in that part.

# %% [markdown]
# ## Conclusion section
#
#   Overall, if you love Chinese food, and always looking for Chinese restaurants when traveling, like me; or, maybe you are just sitting in front of a computer and want to explore a location, find some restaurants, this project can give you some useful information.
#
#   It's a shame that I don't have a Foursquare Premium account, otherwise, I would make the effort to extract restaurant's ratings to make this project more valueable.
#
#   This project has shown me a practical application to resolve a real world situation using Data Science tools.
#
#   I feel rewarded with the efforts and time spent. I believe this course with all the topics covered is well worthy of appreciation.

# %% [markdown]
# ## Reference
# Chinese restaurant: https://en.wikipedia.org/wiki/Chinese_restaurant
# Chinese cuisine: https://en.wikipedia.org/wiki/Chinese_cuisine
# List of cities by international visitors: https://en.wikipedia.org/wiki/List_of_cities_by_international_visitors
